# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# DATASET_PATH = 'D:\\Datasets\\MovieLensTagGenome2021\\raw\\'
DATASET_PATH = 'D:\\Datasets\\MovieLens32M\\'

# %% [markdown]
# # MovieLensTagGenome2021

# %%
pd.read_json(DATASET_PATH + "tags.json", lines=True)
# Out:
#                  tag      id
# 0            aardman      22
# 1     secret service     112
# 2         hillarious     167
# 3          christian     270
# 4              mummy     362
# ...              ...     ...
# 1089   disappointing  109147
# 1090         lesbian  109249
# 1091        morality  109333
# 1092     new orleans  109336
# 1093         bad cgi  109660
#
# [1094 rows x 2 columns]

# %%
pd.read_json(DATASET_PATH + "metadata.json", lines=True)
# Out:
#                                                    title  \
# 0                                       Toy Story (1995)
# 1                                         Jumanji (1995)
# 2                                Grumpier Old Men (1995)
# 3                               Waiting to Exhale (1995)
# 4                     Father of the Bride Part II (1995)
# ...                                                  ...
# 84656                             The Tenth Level (1976)
# 84657                                   Nightmare (1974)
# 84658                                     Pee Nak (2019)
# 84659                                   Pee Nak 2 (2020)
# 84660  The Making of the Philadelphia Eagles Cheerlea...
#
#                          directedBy  \
# 0                     John Lasseter
# 1                      Joe Johnston
# 2                     Howard Deutch
# 3                   Forest Whitaker
# 4                     Charles Shyer
# ...                             ...
# ...

# %% [markdown]
# # MovieLens32M

# %%
# read all the csv file names in the DATASET_PATH folder
csv_files = [f for f in os.listdir(DATASET_PATH) if f.endswith('.csv')]
csv_files
# Out:
# ['links.csv', 'movies.csv', 'ratings.csv', 'tags.csv']

# %%
pd.read_csv(DATASET_PATH + "links.csv")
# Out:
#        movieId    imdbId     tmdbId
# 0            1    114709      862.0
# 1            2    113497     8844.0
# 2            3    113228    15602.0
# 3            4    114885    31357.0
# 4            5    113041    11862.0
# ...        ...       ...        ...
# 87580   292731  26812510  1032473.0
# 87581   292737  14907358   986674.0
# 87582   292753  12388280   948139.0
# 87583   292755     64027   182776.0
# 87584   292757  28995566  1174725.0
#
# [87585 rows x 3 columns]

# %%
pd.read_csv(DATASET_PATH + "movies.csv")
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 87580   292731           The Monroy Affaire (2022)
# 87581   292737          Shelter in Solitude (2023)
# 87582   292753                         Orca (2023)
# 87583   292755              The Angry Breed (1968)
# 87584   292757           Race to the Summit (2023)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
ratings = pd.read_csv(DATASET_PATH + "ratings.csv")
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1       17     4.0   944249077
# 1              1       25     1.0   944250228
# 2              1       29     2.0   943230976
# 3              1       30     5.0   944249077
# 4              1       32     5.0   943228858
# ...          ...      ...     ...         ...
# 32000199  200948    79702     4.5  1294412589
# 32000200  200948    79796     1.0  1287216292
# 32000201  200948    80350     0.5  1294412671
# 32000202  200948    80463     3.5  1350423800
# 32000203  200948    87304     4.5  1350423523
#
# [32000204 rows x 4 columns]

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### user-item matrix

# %%
# create user-item matrix
n_users = ratings.userId.unique().shape[0]
n_movies = ratings.movieId.unique().shape[0]

print("Number of users: ", n_users)
print("Number of movies: ", n_movies)
# Out:
# Number of users:  200948
# Number of movies:  84432

# %%
ratings.userId.value_counts().describe()
# Out:
# count    200948.000000
# mean        159.246193
# std         282.025462
# min          20.000000
# 25%          36.000000
# 50%          73.000000
# 75%         167.000000
# max       33332.000000
# Name: count, dtype: float64

# %%
ratings.movieId.value_counts().describe()
# Out:
# count     84432.000000
# mean        379.005638
# std        2592.439791
# min           1.000000
# 25%           2.000000
# 50%           5.000000
# 75%          25.000000
# max      102929.000000
# Name: count, dtype: float64

# %%
# calculate sparsity
sparsity = 1 - ratings.shape[0] / (n_users * n_movies)
print("Sparsity: ", sparsity)
# Out:
# Sparsity:  0.9981139118693746

# %%
tags = pd.read_csv(DATASET_PATH + "tags.csv")
tags
# Out:
#          userId  movieId             tag   timestamp
# 0            22    26479     Kevin Kline  1583038886
# 1            22    79592        misogyny  1581476297
# 2            22   247150      acrophobia  1622483469
# 3            34     2174           music  1249808064
# 4            34     2174           weird  1249808102
# ...         ...      ...             ...         ...
# 2000067  162279    90645      Rafe Spall  1320817734
# 2000068  162279    91079   Anton Yelchin  1322337407
# 2000069  162279    91079  Felicity Jones  1322337400
# 2000070  162279    91658     Rooney Mara  1325828398
# 2000071  162279   100714     Julie Delpy  1373095449
#
# [2000072 rows x 4 columns]

# %%
tags.movieId.value_counts()
# Out:
# movieId
# 296       6697
# 79132     6568
# 260       6519
# 2571      5722
# 2959      5532
#           ...
# 188167       1
# 188157       1
# 188155       1
# 159781       1
# 128049       1
# Name: count, Length: 51323, dtype: int64

# %%
tags.tag.value_counts()
# Out:
# tag
# sci-fi                     10996
# atmospheric                 9589
# action                      8473
# comedy                      8139
# funny                       7467
#                            ...
# bad behavior                   1
# apache junction arizona        1
# advent calendar                1
# adult hitting a child          1
# Clemence Poesy                 1
# Name: count, Length: 140979, dtype: int64

# %%
# find the number of tags that are mentioned only once
tags.tag.value_counts().value_counts()
# Out:
# count
# 1        73175
# 2        19911
# 3         9569
# 4         5797
# 5         4101
#          ...
# 756          1
# 755          1
# 326          1
# 754          1
# 10996        1
# Name: count, Length: 929, dtype: int64
